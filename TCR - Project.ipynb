# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv("bank-full.csv", sep=';') 
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
print(f'Data contains {data.shape[0]} samples and {data.shape[1]} variables')

TARGET_COL='y'

features = [c for c in data.columns if c not in [TARGET_COL]]
print(f'\nThe dataset contains {len(features)} input features')
# Out:
# Data contains 45211 samples and 17 variables
#
# The dataset contains 16 input features

# %%
data[TARGET_COL].value_counts(normalize='True')
# Out:
# y
# no     0.883015
# yes    0.116985
# Name: proportion, dtype: float64

# %%
sns.countplot(data[TARGET_COL])
plt.title("Target Distribution", fontsize=14)
# Out:
# Text(0.5, 1.0, 'Target Distribution')

# %%
data[features].isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
print(data.shape)
data = data.drop_duplicates()
print(data.shape)
# Out:
# (45211, 17)
# (45211, 17)

# %%
data.nunique()
# Out:
# age            77
# job            12
# marital         3
# education       4
# default         2
# balance      7168
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1573
# campaign       48
# pdays         559
# previous       41
# poutcome        4
# y               2
# dtype: int64

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
cat_cols = ['job','marital','education','default','housing','loan','contact','month', 'poutcome']

num_cols = [c for c in features if c not in cat_cols]
num_cols
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
fig, axes = plt.subplots(5, 2, figsize=(16, 16)) 
axes = [ax for axes_row in axes for ax in axes_row]

for i, c in enumerate(data[cat_cols]):
    _ = data[c].value_counts()[::-1].plot(kind = 'barh', ax=axes[i], title=c, fontsize=14)
    
_ = plt.tight_layout()

# %%
for c in cat_cols:
    plt.figure(figsize=(18,6)) 
    sns.countplot(x =c, hue='y',data = data,order = data[c].value_counts().index)

# %%
data1= data.copy()

data1['y'] = data1['y'].replace(['no','yes'],[0,1]) 
data1.head()

total_subscribers = data1.groupby('job').y.sum().values

proportion_subscribed = (round(data1.groupby('job').y.sum()/data1.groupby('job').y.count(),3)*100).values

total_people = data1.groupby('job').y.count().values

jobs = sorted(data1.job.unique()) 
jobs_with_subscribers = pd.DataFrame({'Job': jobs, 'Total Subscribers':total_subscribers,'Total People in Job': total_people,'Proportion of Subscribers': proportion_subscribed})
jobs_with_subscribers.sort_values(by='Proportion of Subscribers', ascending=False)
# Out:
# /var/folders/yf/8mln4q912nvf3r3qlr7n80rr0000gn/T/ipykernel_11985/1748584405.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data1['y'] = data1['y'].replace(['no','yes'],[0,1])
#               Job  Total Subscribers  Total People in Job  \
# 8         student                269                  938
# 5         retired                516                 2264
# 10     unemployed                202                 1303
# 4      management               1301                 9458
# 0          admin.                631                 5171
# 6   self-employed                187                 1579
# 11        unknown                 34                  288
# 9      technician                840                 7597
# 7        services                369                 4154
# 3       housemaid                109                 1240
# 2    entrepreneur                123                 1487
# 1     blue-collar                708                 9732
#
#     Proportion of Subscribers
# 8                        28.7
# 5                        22.8
# 10                       15.5
# 4                        13.8
# 0                        12.2
# 6                        11.8
# 11                       11.8
# 9                        11.1
# 7                         8.9
# 3                         8.8
# 2                         8.3
# 1                         7.3

# %%
married_subscribers = data1[(data1.marital=='married') ].y.sum()
single_subscribers = data1[(data1.marital=='single') | (data1.marital=='divorced')].y.sum() 

married_subscribers_prop = married_subscribers/len(data1[data1.marital=='married'])
single_subscribers_prop = single_subscribers/len(data1[(data1.marital=='single') | (data1.marital=='divorced')])

print('No of Married clients who subscribe: {}'.format(married_subscribers))
print('No of Single (and divorced) clients who subscribe : {}'.format(single_subscribers))

print('Married clients campaign success rate: {0:.0f}%'.format(married_subscribers_prop*100))
print('Single clients campaign success rate: {0:.0f}%'.format(single_subscribers_prop*100))
# Out:
# No of Married clients who subscribe: 2755
# No of Single (and divorced) clients who subscribe : 2534
# Married clients campaign success rate: 10%
# Single clients campaign success rate: 14%

# %%
fig, axes = plt.subplots(10, 1, figsize=(8, 20))
for i, c in enumerate(num_cols):
  _ = data[[c]].boxplot(ax=axes[i], vert=False)

# %%
fig, axes = plt.subplots(10, 1, figsize=(8, 60))
for i, c in enumerate(num_cols):
  sns.boxplot(data=data,x='y',y=c,ax=axes[i])

# %%
sns.set(font_scale=1.3)
fig, axes = plt.subplots(5, 2, figsize=(18, 14))
axes = [ax for axes_row in axes for ax in axes_row]
for i, c in enumerate(num_cols):
  plot = sns.kdeplot(data=data, x=c, ax=axes[i], fill=True)
plt.tight_layout()

# %%
sns.set(font_scale=1.3)
fig, axes = plt.subplots(5, 2, figsize=(18, 14))
axes = [ax for axes_row in axes for ax in axes_row]
for i, c in enumerate(num_cols):
  plot = sns.kdeplot(data=data, x=c, hue=TARGET_COL, multiple='fill', ax=axes[i])
plt.tight_layout()

# %%
sns.set(font_scale=1.3)
fig, axes = plt.subplots(5, 2, figsize=(18, 14))
axes = [ax for axes_row in axes for ax in axes_row]
for i, c in enumerate(num_cols):
  plot = data.groupby(TARGET_COL)[c].median().plot(kind = 'barh', title=f'Median_{c}', ax=axes[i])
plt.tight_layout()

# %%
n1=len(data[(data['age'] > 60) & (data['y'] == 'yes')]) 
n2=len(data[(data['age'] > 60) & (data['y'] == 'no')]) 
n3=len(data[(data['age'] <= 60) & (data['y'] == 'yes')]) 
n4=len(data[(data['age'] <= 60) & (data['y'] == 'no')]) 

print(f'Proportion of young subscribers is: {n3/(n3+n4)} and the proportion of old subscribers is {n1/(n1+n2)}')
# Out:
# Proportion of young subscribers is: 0.10873861390636713 and the proportion of old subscribers is 0.4225589225589226

# %%
plt.figure(figsize=(14, 8))
_ = sns.heatmap(data[num_cols].corr(), annot=True)

# %%
data= data.drop(['duration','campaign'],axis=1)
data.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  pdays  previous poutcome   y
# 0  unknown    5   may     -1         0  unknown  no
# 1  unknown    5   may     -1         0  unknown  no
# 2  unknown    5   may     -1         0  unknown  no
# 3  unknown    5   may     -1         0  unknown  no
# 4  unknown    5   may     -1         0  unknown  no

# %%
data['y'] = data['y'].replace(['no','yes'],[0,1])
data.head()
# Out:
# /var/folders/yf/8mln4q912nvf3r3qlr7n80rr0000gn/T/ipykernel_11985/2397172530.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['y'] = data['y'].replace(['no','yes'],[0,1])
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  pdays  previous poutcome  y
# 0  unknown    5   may     -1         0  unknown  0
# 1  unknown    5   may     -1         0  unknown  0
# 2  unknown    5   may     -1         0  unknown  0
# 3  unknown    5   may     -1         0  unknown  0
# 4  unknown    5   may     -1         0  unknown  0

# %%
feat = [c for c in data.columns if c not in [TARGET_COL]]
len(feat)

from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.33)
print(train.shape)
print(test.shape)
# Out:
# (30291, 15)
# (14920, 15)

# %%
train_X, test_X = train[feat], test[feat]

train_y, test_y = train[TARGET_COL], test[TARGET_COL]

# %%
preds_test = np.zeros(len(test_X))

from sklearn.metrics import accuracy_score, f1_score
accuracy = accuracy_score(test_y, preds_test)
f1 = f1_score(test_y, preds_test)

print(f'Accuracy score is: {accuracy}')
print(f'F1 score is: {f1}')
# Out:
# Accuracy score is: 0.8806300268096515
# F1 score is: 0.0

# %%
from sklearn.metrics import roc_auc_score,roc_curve,auc,confusion_matrix,classification_report
print("Confusion Matrix is:")
print(confusion_matrix(test_y, preds_test))
# Out:
# Confusion Matrix is:
# [[13139     0]
#  [ 1781     0]]

# %%
print("AUC on Test data is " +str(roc_auc_score(test_y,preds_test)))
# Out:
# AUC on Test data is 0.5

# %%
np.random.seed(2)

preds_test = np.random.choice([0, 1], size=len(test_y))

f1_score(test_y, preds_test)
# Out:
# 0.1932075471698113

# %%
print("Confusion Matrix is:")
print(confusion_matrix(test_y, preds_test))
# Out:
# Confusion Matrix is:
# [[6541 6598]
#  [ 885  896]]

# %%
print("AUC on Test data is " +str(roc_auc_score(test_y,preds_test)))
# Out:
# AUC on Test data is 0.500459518937133

# %%
train.shape, test.shape
# Out:
# ((30291, 15), (14920, 15))

# %%
train.head()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 20627   31   technician   single   tertiary      no      208      no   no
# 29321   57      retired  married  secondary      no      485      no   no
# 8761    34     services  married  secondary      no     -211     yes   no
# 3482    33   management   single   tertiary      no     -625     yes   no
# 27375   36  blue-collar  married  secondary      no     3266     yes   no
#
#         contact  day month  pdays  previous poutcome  y
# 20627  cellular   12   aug     -1         0  unknown  1
# 29321  cellular    2   feb    187         2  failure  0
# 8761    unknown    4   jun     -1         0  unknown  0
# 3482    unknown   15   may     -1         0  unknown  0
# 27375  cellular   21   nov     -1         0  unknown  0

# %%
df = pd.concat([train, test], axis=0).reset_index(drop = True)  
df.shape
# Out:
# (45211, 15)

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   31   technician   single   tertiary      no      208      no   no
# 1   57      retired  married  secondary      no      485      no   no
# 2   34     services  married  secondary      no     -211     yes   no
# 3   33   management   single   tertiary      no     -625     yes   no
# 4   36  blue-collar  married  secondary      no     3266     yes   no
#
#     contact  day month  pdays  previous poutcome  y
# 0  cellular   12   aug     -1         0  unknown  1
# 1  cellular    2   feb    187         2  failure  0
# 2   unknown    4   jun     -1         0  unknown  0
# 3   unknown   15   may     -1         0  unknown  0
# 4  cellular   21   nov     -1         0  unknown  0

# %%
df.drop(['month'],axis=1,inplace=True)
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   31   technician   single   tertiary      no      208      no   no
# 1   57      retired  married  secondary      no      485      no   no
# 2   34     services  married  secondary      no     -211     yes   no
# 3   33   management   single   tertiary      no     -625     yes   no
# 4   36  blue-collar  married  secondary      no     3266     yes   no
#
#     contact  day  pdays  previous poutcome  y
# 0  cellular   12     -1         0  unknown  1
# 1  cellular    2    187         2  failure  0
# 2   unknown    4     -1         0  unknown  0
# 3   unknown   15     -1         0  unknown  0
# 4  cellular   21     -1         0  unknown  0

# %%
new_cat_cols=['job','marital','education','default','housing','loan','contact','poutcome']
for c in new_cat_cols:
  print(df[c].value_counts())
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64
# education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64
# default
# no     44396
# yes      815
# Name: count, dtype: int64
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64
# poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (45211, 14)

# %%
index_names= df[(df.job == 'unknown') | (df.marital == 'unknown') | (df.education == 'unknown') | (df.default == 'unknown') | (df.housing == 'unknown') | (df.loan == 'unknown')].index

df.drop(index_names, inplace = True) 
df.shape
# Out:
# (43193, 14)

# %%
new_cat_cols=['job','marital','education','default','housing','loan','contact','poutcome']
for c in new_cat_cols:
  print(df[c].value_counts())
# Out:
# job
# blue-collar      9278
# management       9216
# technician       7355
# admin.           5000
# services         4004
# retired          2145
# self-employed    1540
# entrepreneur     1411
# unemployed       1274
# housemaid        1195
# student           775
# Name: count, dtype: int64
# marital
# married     25946
# single      12219
# divorced     5028
# Name: count, dtype: int64
# education
# secondary    23131
# tertiary     13262
# primary       6800
# Name: count, dtype: int64
# default
# no     42411
# yes      782
# Name: count, dtype: int64
# housing
# yes    24292
# no     18901
# Name: count, dtype: int64
# loan
# no     36086
# yes     7107
# Name: count, dtype: int64
# contact
# cellular     28213
# unknown      12286
# telephone     2694
# Name: count, dtype: int64
# poutcome
# unknown    35286
# failure     4709
# other       1774
# success     1424
# Name: count, dtype: int64

# %%
df= pd.get_dummies(df,columns=new_cat_cols)
df.head()
# Out:
#    age  balance  day  pdays  previous  y  job_admin.  job_blue-collar  \
# 0   31      208   12     -1         0  1       False            False
# 1   57      485    2    187         2  0       False            False
# 2   34     -211    4     -1         0  0       False            False
# 3   33     -625   15     -1         0  0       False            False
# 4   36     3266   21     -1         0  0       False             True
#
#    job_entrepreneur  job_housemaid  ...  housing_yes  loan_no  loan_yes  \
# 0             False          False  ...        False     True     False
# 1             False          False  ...        False     True     False
# 2             False          False  ...         True     True     False
# 3             False          False  ...         True     True     False
# 4             False          False  ...         True     True     False
#
#    contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# 0              True              False            False             False
# 1              True              False            False              True
# 2             False              False             True             False
# 3             False              False             True             False
# 4              True              False            False             False
#
#    poutcome_other  poutcome_success  poutcome_unknown
# 0           False             False              True
# 1           False             False             False
# 2           False             False              True
# 3           False             False              True
# 4           False             False              True
#
# [5 rows x 36 columns]

# %%
df['pdays'].value_counts()
# Out:
# pdays
# -1      35281
#  182      151
#  92       138
#  183      120
#  91       115
#         ...
#  826        1
#  432        1
#  419        1
#  595        1
#  407        1
# Name: count, Length: 557, dtype: int64

# %%
df['has_contacted'] = np.where(df['pdays']!= 999, True, False)

df.drop(['pdays'],axis=1,inplace=True)

df.head()
# Out:
#    age  balance  day  previous  y  job_admin.  job_blue-collar  \
# 0   31      208   12         0  1       False            False
# 1   57      485    2         2  0       False            False
# 2   34     -211    4         0  0       False            False
# 3   33     -625   15         0  0       False            False
# 4   36     3266   21         0  0       False             True
#
#    job_entrepreneur  job_housemaid  job_management  ...  loan_no  loan_yes  \
# 0             False          False           False  ...     True     False
# 1             False          False           False  ...     True     False
# 2             False          False           False  ...     True     False
# 3             False          False            True  ...     True     False
# 4             False          False           False  ...     True     False
#
#    contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# 0              True              False            False             False
# 1              True              False            False              True
# 2             False              False             True             False
# 3             False              False             True             False
# 4              True              False            False             False
#
#    poutcome_other  poutcome_success  poutcome_unknown  has_contacted
# 0           False             False              True           True
# 1           False             False             False           True
# 2           False             False              True           True
# 3           False             False              True           True
# 4           False             False              True           True
#
# [5 rows x 36 columns]

# %%
df= pd.get_dummies(df,columns=['has_contacted'])
df.head()
# Out:
#    age  balance  day  previous  y  job_admin.  job_blue-collar  \
# 0   31      208   12         0  1       False            False
# 1   57      485    2         2  0       False            False
# 2   34     -211    4         0  0       False            False
# 3   33     -625   15         0  0       False            False
# 4   36     3266   21         0  0       False             True
#
#    job_entrepreneur  job_housemaid  job_management  ...  loan_no  loan_yes  \
# 0             False          False           False  ...     True     False
# 1             False          False           False  ...     True     False
# 2             False          False           False  ...     True     False
# 3             False          False            True  ...     True     False
# 4             False          False           False  ...     True     False
#
#    contact_cellular  contact_telephone  contact_unknown  poutcome_failure  \
# 0              True              False            False             False
# 1              True              False            False              True
# 2             False              False             True             False
# 3             False              False             True             False
# 4              True              False            False             False
#
#    poutcome_other  poutcome_success  poutcome_unknown  has_contacted_True
# 0           False             False              True                True
# 1           False             False             False                True
# 2           False             False              True                True
# 3           False             False              True                True
# 4           False             False              True                True
#
# [5 rows x 36 columns]

# %%
features = [c for c in df.columns if c not in [TARGET_COL]]
len(features)
# Out:
# 35

# %%
trn, test = train_test_split(df, test_size=0.2, random_state = 1, stratify = df[TARGET_COL]) #stratified sampling
trn.shape, test.shape
# Out:
# ((34554, 36), (8639, 36))

# %%
trn.head()
# Out:
#        age  balance  day  previous  y  job_admin.  job_blue-collar  \
# 17671   45      229    5         0  0       False            False
# 6843    46     -319   10         0  0       False             True
# 255     34      302    7         0  0       False            False
# 43941   28        0    3         0  0       False             True
# 22213   51     7848   18         0  0       False            False
#
#        job_entrepreneur  job_housemaid  job_management  ...  loan_no  \
# 17671             False          False           False  ...     True
# 6843              False          False           False  ...    False
# 255               False          False           False  ...     True
# 43941             False          False           False  ...    False
# 22213             False          False           False  ...     True
#
#        loan_yes  contact_cellular  contact_telephone  contact_unknown  \
# 17671     False             False              False             True
# 6843       True              True              False            False
# 255       False             False              False             True
# 43941      True             False              False             True
# 22213     False              True              False            False
#
#        poutcome_failure  poutcome_other  poutcome_success  poutcome_unknown  \
# 17671             False           False             False              True
# 6843              False           False             False              True
# 255               False           False             False              True
# 43941             False           False             False              True
# 22213             False           False             False              True
#
#        has_contacted_True
# 17671                True
# 6843                 True
# 255                  True
# 43941                True
# 22213                True
#
# [5 rows x 36 columns]

# %%
X_trn, X_test = trn[features], test[features]

y_trn, y_test = trn[TARGET_COL], test[TARGET_COL]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
_ = scaler.fit(X_trn)
X_trn = scaler.transform(X_trn)
#X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

lr = LogisticRegression(max_iter=7600,random_state = 1)
_ = lr.fit(X_trn, y_trn)

preds_test= lr.predict(X_test)

f1_score(y_test, preds_test)
# Out:
# 0.2816679779701023

# %%
print("Confusion Matrix is:")
print(confusion_matrix(y_test, preds_test))
# Out:
# Confusion Matrix is:
# [[7547   88]
#  [ 825  179]]

# %%
pd.crosstab(y_test, preds_test, rownames=['Actual'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# Actual
# 0          7547   88  7635
# 1           825  179  1004
# All        8372  267  8639

# %%
pd.crosstab(y_test, preds_test, rownames=['Actual'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# Actual
# 0          7547   88  7635
# 1           825  179  1004
# All        8372  267  8639

# %%
dt = DecisionTreeClassifier(random_state = 1)
_ = dt.fit(X_trn, y_trn)

preds_test= dt.predict(X_test)

f1_score(y_test, preds_test)
# Out:
# 0.2923286427598729

# %%
from sklearn.model_selection import RandomizedSearchCV

hyperparam_combs = {
    'max_depth': [4, 6, 8, 10, 12],
    'criterion': ['gini', 'entropy'],
    'min_samples_split': [2, 10, 20, 30, 40],
    'max_features': [0.2, 0.4, 0.6, 0.8, 1],
    'max_leaf_nodes': [8, 16, 32, 64, 128],
    'class_weight': [{0: 1, 1: 1}, {0: 1, 1: 2}, {0: 1, 1: 3}, {0: 1, 1: 4}, {0: 1, 1: 5}]
}

dt2 = RandomizedSearchCV(DecisionTreeClassifier(),
                         hyperparam_combs,
                         scoring='f1',
                         random_state=1,
                         n_iter=30)

search = dt2.fit(X_trn, y_trn)

search.best_params_
# Out:
# {'min_samples_split': 20,
#  'max_leaf_nodes': 32,
#  'max_features': 0.8,
#  'max_depth': 10,
#  'criterion': 'gini',
#  'class_weight': {0: 1, 1: 3}}

# %%
optimal_params = {
 'criterion': 'entropy',
 'max_depth': 10,
 'max_features': 0.6,
 'max_leaf_nodes': 32,
 'min_samples_split': 20,
 'class_weight': {0: 1, 1: 3}}

dt2 = DecisionTreeClassifier(random_state = 1, **optimal_params)
_ = dt2.fit(X_trn, y_trn)

preds_test= dt2.predict(X_test)

f1_score(y_test, preds_test)
# Out:
# 0.410201912858661

# %%
print("Confusion Matrix is:")
print(confusion_matrix(y_test, preds_test))
# Out:
# Confusion Matrix is:
# [[7143  492]
#  [ 618  386]]

# %%
pd.crosstab(y_test, preds_test, rownames=['Actual'], colnames=['Predicted'], margins=True)
# Out:
# Predicted     0    1   All
# Actual
# 0          7143  492  7635
# 1           618  386  1004
# All        7761  878  8639

# %%
print("AUC on Test data is " +str(roc_auc_score(y_test,preds_test)))
# Out:
# AUC on Test data is 0.6600110364044803

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=1) 
rf.fit(X_trn, y_trn)

preds_test= rf.predict(X_test)

f1_score(y_test, preds_test)
# Out:
# 0.29420505200594355

# %%
print('Parameters currently in use:\n')
print(rf.get_params())
# Out:
# Parameters currently in use:
#
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': None, 'oob_score': False, 'random_state': 1, 'verbose': 0, 'warm_start': False}

# %%
def plot_feature_importances(model):
    n_features = X_trn.shape[1]
    plt.figure(figsize=(12,12))
    plt.barh(range(n_features), model.feature_importances_, align='center') 
    plt.yticks(np.arange(n_features), trn[features].columns.values) 
    plt.xlabel("Feature importance")
    plt.ylabel("Feature")

plot_feature_importances(rf)

# %%
import joblib
import os
os.makedirs('backend/model', exist_ok=True)
joblib.dump(rf, 'backend/model/model.pkl')
joblib.dump(scaler, 'backend/model/scaler.pkl')
print("model.pkl and scaler.pkl saved successfully")
# Out:
# model.pkl and scaler.pkl saved successfully
